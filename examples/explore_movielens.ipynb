# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# Exploração inicial do MovieLens (ml-latest-small)\n",
    "\n",
    "Este notebook carrega e faz uma exploração inicial dos dados de filmes e avaliações do MovieLens."
   ]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "# Importando bibliotecas\n",
    "import pandas as pd\n",
    "import os"
   ],
   "execution_count": null,
   "outputs": []
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## Caminho para os dados"
   ]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "# Defina o caminho para os arquivos CSV\n",
    "DATA_PATH = os.path.join('..', 'data', 'ml-latest-small')\n",
    "RATINGS_FILE = os.path.join(DATA_PATH, 'ratings.csv')\n",
    "MOVIES_FILE = os.path.join(DATA_PATH, 'movies.csv')"
   ],
   "execution_count": null,
   "outputs": []
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## Carregando os arquivos"
   ]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "ratings = pd.read_csv(RATINGS_FILE)\n",
    "movies = pd.read_csv(MOVIES_FILE)\n",
    "\n",
    "print(f'ratings.shape = {ratings.shape}')\n",
    "print(f'movies.shape = {movies.shape}')"
   ],
   "execution_count": null,
   "outputs": []
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## Visualizando as primeiras linhas dos dados"
   ]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "ratings.head()"
   ],
   "execution_count": null,
   "outputs": []
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "movies.head()"
   ],
   "execution_count": null,
   "outputs": []
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## Estatísticas básicas"
   ]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "# Quantidade de usuários únicos, filmes únicos e ratings\n",
    "num_users = ratings['userId'].nunique()\n",
    "num_movies = ratings['movieId'].nunique()\n",
    "num_ratings = len(ratings)\n",
    "print(f'Usuários únicos: {num_users}')\n",
    "print(f'Filmes únicos: {num_movies}')\n",
    "print(f'Ratings totais: {num_ratings}')"
   ],
   "execution_count": null,
   "outputs": []
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "# Estatísticas das avaliações\n",
    "ratings['rating'].describe()"
   ],
   "execution_count": null,
   "outputs": []
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## Exemplos de filmes mais populares"
   ]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "# Top 10 filmes mais avaliados\n",
    "top_movies = ratings['movieId'].value_counts().head(10).index\n",
    "movies[movies['movieId'].isin(top_movies)]"
   ],
   "execution_count": null,
   "outputs": []
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  },
  "language_info": {
   "name": "python",
   "version": ""
  }
 },
 "nbformat": 4,
 "nbformat_minor": 4
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 20
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "markdown",
#       5    "metadata": {},
#       6    "source": [
#       7     "# Exploração inicial do MovieLens (ml-latest-small)\n",
#       8     "\n",
#       9     "Este notebook carrega e faz uma exploração inicial dos dados de filmes e avaliações do MovieLens."
#      10    ]
#      11   },
#      12   {
#      13    "cell_type": "code",
#      14    "metadata": {},
#      15    "source": [
#      16     "# Importando bibliotecas\n",
#      17     "import pandas as pd\n",
#      18     "import os"
#      19    ],
# ---> 20    "execution_count": null,
#      21    "outputs": []
#      22   },
#      23   {
#      24    "cell_type": "markdown",
#      25    "metadata": {},
#      26    "source": [
# ...
